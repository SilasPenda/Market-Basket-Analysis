# %%
import pandas as pd
import numpy as np
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
df = pd.read_csv('sales_data.csv')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
df.shape
# Out:
# (1609280, 8)

# %%
df.Description = df.Description.str.strip()
df.dropna(axis = 0, subset=['InvoiceNo'], inplace=True)
df.InvoiceNo = df.InvoiceNo.astype('str') # convert invoice number to string so algorithm will understand it
df = df[~df.InvoiceNo.str.contains('C')] # remove all credit transactions

# %%
df.Country.value_counts()
# Out:
# United Kingdom          1452302
# Germany                   25745
# EIRE                      25248
# France                    22349
# Netherlands                7456
# Spain                      6205
# Switzerland                5104
# Belgium                    5100
# Portugal                   4063
# Australia                  3000
# Norway                     2509
# Channel Islands            2317
# Italy                      2226
# Sweden                     1789
# Cyprus                     1769
# Finland                    1717
# Austria                    1320
# Unspecified                1198
# Denmark                    1178
# Poland                      842
# Japan                       806
# Greece                      802
# Israel                      664
# Hong Kong                   642
# USA                         588
# Singapore                   561
# United Arab Emirates        535
# Iceland                     435
# Malta                       394
# Canada                      379
# RSA                         226
# Lithuania                   224
# Bahrain                     142
# Brazil                      126
# European Community          120
# Lebanon                     102
# Thailand                     76
# West Indies                  54
# Korea                        53
# Czech Republic               50
# Bermuda                      34
# Nigeria                      30
# Saudi Arabia                 18
# Name: Country, dtype: int64

# %%
# Only run analysis for German customers
my_basket  = (df[df.Country == 'Germany'].groupby(['InvoiceNo', 'Description'])['Quantity'].sum().unstack().reset_index().fillna(0).set_index('InvoiceNo'))

# %%
my_basket.head()
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 489526                          0.0                         0.0
# 490395                          0.0                         0.0
# 490563                          0.0                         0.0
# 490564                          0.0                         0.0
# 490682                          0.0                         0.0
#
# Description  12 IVORY ROSE PEG PLACE SETTINGS  \
# InvoiceNo
# 489526                                    0.0
# 490395                                    0.0
# 490563                                    0.0
# 490564                                    0.0
# 490682                                    0.0
#
# Description  12 MESSAGE CARDS WITH ENVELOPES  12 MINI TOADSTOOL PEGS  \
# InvoiceNo
# 489526                                   0.0                     0.0
# 490395                                   0.0                     0.0
# 490563                                   0.0                     0.0
# 490564                                   0.0                     0.0
# 490682                                   0.0                     0.0
#
# Description  12 PENCIL SMALL TUBE WOODLAND  \
# InvoiceNo
# 489526                                 0.0
# 490395                                 0.0
# 490563                                 0.0
# 490564                                 0.0
# 490682                                 0.0
#
# Description  12 PENCILS SMALL TUBE RED RETROSPOT  \
# InvoiceNo
# 489526                                       0.0
# 490395                                       0.0
# 490563                                       0.0
# 490564                                       0.0
# 490682                                       0.0
#
# Description  12 PENCILS SMALL TUBE RED SPOTTY  12 PENCILS SMALL TUBE SKULL  \
# InvoiceNo
# 489526                                    0.0                          0.0
# 490395                                    0.0                          0.0
# 490563                                    0.0                          0.0
# 490564                                    0.0                          0.0
# 490682                                    0.0                          0.0
#
# Description  12 PENCILS TALL TUBE POSY  ...  ZINC  HEART T-LIGHT HOLDER  \
# InvoiceNo                               ...
# 489526                             0.0  ...                         0.0
# 490395                             0.0  ...                         0.0
# 490563                             0.0  ...                         0.0
# 490564                             0.0  ...                         0.0
# 490682                             0.0  ...                         0.0
#
# Description  ZINC  STAR T-LIGHT HOLDER  ZINC BOX SIGN HOME  \
# InvoiceNo
# 489526                             0.0                 0.0
# 490395                             0.0                 0.0
# 490563                             0.0                 0.0
# 490564                             0.0                 0.0
# 490682                             0.0                 0.0
#
# Description  ZINC FOLKART SLEIGH BELLS  ZINC HEART LATTICE T-LIGHT HOLDER  \
# InvoiceNo
# 489526                             0.0                                0.0
# 490395                             0.0                                0.0
# 490563                             0.0                                0.0
# 490564                             0.0                                0.0
# 490682                             0.0                                0.0
#
# Description  ZINC METAL HEART DECORATION  ZINC T-LIGHT HOLDER STAR LARGE  \
# InvoiceNo
# 489526                              24.0                             0.0
# 490395                               0.0                             0.0
# 490563                               0.0                             0.0
# 490564                               0.0                             0.0
# 490682                               0.0                             0.0
#
# Description  ZINC T-LIGHT HOLDER STARS SMALL  ZINC TOP  2 DOOR WOODEN SHELF  \
# InvoiceNo
# 489526                                   0.0                            0.0
# 490395                                   0.0                            0.0
# 490563                                   0.0                            0.0
# 490564                                   0.0                            0.0
# 490682                                   0.0                            0.0
#
# Description  ZINC WILLIE WINKIE  CANDLE STICK
# InvoiceNo
# 489526                                   24.0
# 490395                                    0.0
# 490563                                    0.0
# 490564                                    0.0
# 490682                                    0.0
#
# [5 rows x 2402 columns]

# %%
# Convert all positive values to 1 and every other thing to 0
def encoded_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1

my_basket_sets = my_basket.applymap(encoded_units)
my_basket_sets.drop('POSTAGE', axis='columns', inplace=True) # Remove postage as an item as it doesn't make much sense

# %% [markdown]
# ### Train Model

# %%
# Generate frequent itemsets
freq_itemsets = apriori(my_basket_sets, min_support=0.07, use_colnames=True)
# Out:
# C:\Users\sapen\anaconda3\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:111: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(

# %%
# Create rules
rules = association_rules(freq_itemsets, metric='lift', min_threshold=1)

# %%
rules.head()
# Out:
#                             antecedents                           consequents  \
# 0    (PLASTERS IN TIN WOODLAND ANIMALS)  (ROUND SNACK BOXES SET OF4 WOODLAND)
# 1  (ROUND SNACK BOXES SET OF4 WOODLAND)    (PLASTERS IN TIN WOODLAND ANIMALS)
# 2   (ROUND SNACK BOXES SET OF 4 FRUITS)  (ROUND SNACK BOXES SET OF4 WOODLAND)
# 3  (ROUND SNACK BOXES SET OF4 WOODLAND)   (ROUND SNACK BOXES SET OF 4 FRUITS)
# 4  (ROUND SNACK BOXES SET OF4 WOODLAND)              (WOODLAND CHARLOTTE BAG)
#
#    antecedent support  consequent support   support  confidence      lift  \
# 0            0.135615            0.262357  0.072243    0.532710  2.030475
# 1            0.262357            0.135615  0.072243    0.275362  2.030475
# 2            0.169835            0.262357  0.136882    0.805970  3.072031
# 3            0.262357            0.169835  0.136882    0.521739  3.072031
# 4            0.262357            0.166033  0.083650    0.318841  1.920345
#
#    leverage  conviction
# 0  0.036664    1.578555
# 1  0.036664    1.192852
# 2  0.092325    3.801696
# 3  0.092325    1.735799
# 4  0.040090    1.224335

# %% [markdown]
# ### Make Recommendations

# %%
# Filter rules based on condition
rules[(rules['lift'] >= 3) & (rules['confidence'] >= 0.3)]
# Out:
#                             antecedents                           consequents  \
# 2   (ROUND SNACK BOXES SET OF 4 FRUITS)  (ROUND SNACK BOXES SET OF4 WOODLAND)
# 3  (ROUND SNACK BOXES SET OF4 WOODLAND)   (ROUND SNACK BOXES SET OF 4 FRUITS)
#
#    antecedent support  consequent support   support  confidence      lift  \
# 2            0.169835            0.262357  0.136882    0.805970  3.072031
# 3            0.262357            0.169835  0.136882    0.521739  3.072031
#
#    leverage  conviction
# 2  0.092325    3.801696
# 3  0.092325    1.735799

# %%
my_basket_sets['ROUND SNACK BOXES SET OF4 WOODLAND'].sum()
# Out:
# 207

# %%
my_basket_sets['ROUND SNACK BOXES SET OF 4 FRUITS'].sum()
# Out:
# 134
